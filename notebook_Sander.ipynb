# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math

# Tensorflow
import tensorflow as tf

# %matplotlib inline

# %%
events = pd.read_csv('data/calcularis_small_events.csv', encoding='latin', low_memory=False)
subtasks = pd.read_csv('data/calcularis_small_subtasks.csv', encoding='latin', low_memory=False)
users = pd.read_csv('data/calcularis_small_users.csv', encoding='latin', low_memory=False)

# %%
events.head(15)
# Out:
#     event_id  user_id       mode                  game_name  learning_time_ms  \
# 0          0        1     NORMAL                 Subitizing       8,835.00000
# 1          1        1     NORMAL                 Conversion      21,167.00000
# 2          2        1     NORMAL                 Conversion      11,182.00000
# 3          3        1     NORMAL                    Landing       6,823.00000
# 4          4        1  END_OF_NR                 Conversion       9,107.00000
# 5          5        1  END_OF_NR                 Conversion      10,703.00000
# 6          6        1     NORMAL                 Comparison       1,383.00000
# 7          7        1  END_OF_NR                    Landing       6,052.00000
# 8          8        1  END_OF_NR                    Landing       6,055.00000
# 9          9        1  END_OF_NR  Estimation on Number Line      10,541.00000
# 10        10        1  END_OF_NR                   Distance      16,811.00000
# 11        11        1  END_OF_NR                    Landing       6,053.00000
# 12        12        2     NORMAL                 Subitizing       4,636.00000
# 13        13        2     NORMAL                 Subitizing       3,366.00000
# 14        14        2     NORMAL                 Subitizing       4,702.00000
#
#    number_range                     start                       end  skill_id  \
# 0           R10  2022-11-02T08:39:12.355Z  2022-11-02T08:39:25.130Z   1.00000
# 1           R10  2022-11-11T10:26:27.893Z  2022-11-11T10:26:49.260Z   4.00000
# 2           R10  2022-11-18T10:34:01.044Z  2022-11-18T10:34:12.423Z   7.00000
# 3           R10  2022-11-25T10:32:43.428Z  2022-11-25T10:32:56.986Z  19.00000
# 4           R10  2022-12-02T10:44:40.555Z  2022-12-02T10:44:49.874Z   7.00000
# 5           R10  2022-12-09T10:12:16.068Z  2022-12-09T10:12:26.984Z   4.00000
# 6           R20  2022-12-16T10:25:42.441Z  2022-12-16T10:25:45.508Z  33.00000
# 7           R20  2023-01-20T10:13:41.496Z  2023-01-20T10:13:49.096Z  50.00000
# 8           R20  2023-01-27T10:18:17.427Z  2023-01-27T10:18:26.356Z  49.00000
# 9           R20  2023-02-03T10:20:25.581Z  2023-02-03T10:20:38.687Z  39.00000
# 10          R20  2023-02-07T11:38:58.002Z  2023-02-07T11:39:17.950Z  45.00000
# 11          R20  2023-02-09T10:23:32.076Z  2023-02-09T10:23:39.868Z  50.00000
# 12          R10  2022-09-07T07:54:24.504Z  2022-09-07T07:55:21.124Z   1.00000
# 13          R10  2022-09-13T09:03:49.380Z  2022-09-13T09:03:56.020Z   1.00000
# 14          R10  2022-09-14T07:24:47.741Z  2022-09-14T07:24:55.085Z   1.00000
#
#     type
# 0   task
# 1   task
# 2   task
# 3   task
# 4   task
# 5   task
# 6   task
# 7   task
# 8   task
# 9   task
# 10  task
# 11  task
# 12  task
# 13  task
# 14  task

# %%
subtasks.head(15)
# Out:
#     subtask_id  event_id  user_id      aim                     answer  \
# 0            0         0        1      NaN                          4
# 1            1         0        1      NaN                          1
# 2            2         1        1      NaN                          3
# 3            3         2        1      NaN                          5
# 4            4         3        1  3.00000   {'a': 2, 'b': 2.0402703}
# 5            5         4        1      NaN                          9
# 6            6         5        1      NaN                          7
# 7            7         6        1      NaN                         16
# 8            8         6        1      NaN                     1.3659
# 9            9         7        1  4.00000    {'a': 4, 'b': 4.148817}
# 10          10         8        1  6.00000    {'a': 7, 'b': 6.968209}
# 11          11         9        1      NaN                         13
# 12          12        10        1      NaN          {'a': 8, 'b': 13}
# 13          13        11        1 11.00000  {'a': 11, 'b': 11.477892}
# 14          14        12        2      NaN                          1
#
#    answerMode availableNumbers  correct   correctAnswerObject  correctNumber  \
# 0         NaN              NaN     True                     4        4.00000
# 1         NaN              NaN     True                   NaN            NaN
# 2         NaN              NaN     True                     3            NaN
# 3         NaN              NaN     True                     5            NaN
# 4         NaN              NaN    False    {'a': 3, 'b': 3.0}            NaN
# 5         NaN              NaN     True                     9            NaN
# 6         NaN              NaN    False                     9            NaN
# 7         NaN              NaN     True                    16            NaN
# 8         NaN              NaN     True                   NaN            NaN
# 9         NaN              NaN     True    {'a': 4, 'b': 4.0}            NaN
# 10        NaN              NaN     True    {'a': 6, 'b': 6.0}            NaN
# 11        NaN              NaN     True                    13            NaN
# 12        NaN              NaN    False     {'a': 8, 'b': 12}            NaN
# 13        NaN              NaN     True  {'a': 11, 'b': 11.0}            NaN
# 14        NaN              NaN     True                     1        1.00000
#
#     ... startPosition  subtask_finished_timestamp  target timeoutInSeconds  \
# 0   ...           NaN    2022-11-02T08:39:24.930Z     NaN              NaN
# 1   ...           NaN    2022-11-02T08:39:24.930Z     NaN          0.00000
# 2   ...           NaN    2022-11-11T10:26:49.007Z     NaN              NaN
# 3   ...           NaN    2022-11-18T10:34:12.191Z     NaN              NaN
# 4   ...       0.50000    2022-11-25T10:32:56.805Z     NaN              NaN
# 5   ...           NaN    2022-12-02T10:44:49.621Z     NaN              NaN
# 6   ...           NaN    2022-12-09T10:12:26.729Z     NaN              NaN
# 7   ...           NaN    2022-12-16T10:25:45.293Z     NaN              NaN
# 8   ...           NaN    2022-12-16T10:25:45.293Z     NaN          4.00000
# 9   ...       0.50000    2023-01-20T10:13:48.879Z     NaN              NaN
# 10  ...       0.50000    2023-01-27T10:18:26.175Z     NaN              NaN
# 11  ...           NaN    2023-02-03T10:20:38.415Z     NaN              NaN
# 12  ...           NaN    2023-02-07T11:39:17.756Z     NaN              NaN
# 13  ...       0.50000    2023-02-09T10:23:39.649Z     NaN              NaN
# 14  ...           NaN    2022-09-07T07:55:20.991Z     NaN              NaN
#
#     timeoutInSteps                                 type  upperBound divisor  \
# 0              NaN     ConciseSubitizingTaskDescription         NaN     NaN
# 1          2.00000            ConciseTimeoutDescription         NaN     NaN
# 2              NaN     ConciseConversionTaskDescription         NaN     NaN
# 3              NaN     ConciseConversionTaskDescription         NaN     NaN
# 4              NaN        ConciseLandingTaskDescription     3.50000     NaN
# 5              NaN     ConciseConversionTaskDescription         NaN     NaN
# 6              NaN     ConciseConversionTaskDescription         NaN     NaN
# 7              NaN  ConciseSetComparisonTaskDescription         NaN     NaN
# 8          0.00000            ConciseTimeoutDescription         NaN     NaN
# 9              NaN        ConciseLandingTaskDescription     5.00000     NaN
# 10             NaN        ConciseLandingTaskDescription     7.00000     NaN
# 11             NaN     ConciseEstimationTaskDescription         NaN     NaN
# 12             NaN     ConciseOrdinalityTaskDescription         NaN     NaN
# 13             NaN        ConciseLandingTaskDescription    12.00000     NaN
# 14             NaN     ConciseSubitizingTaskDescription         NaN     NaN
#
#     orderIndependent  step
# 0                NaN   NaN
# 1                NaN   NaN
# 2                NaN   NaN
# 3                NaN   NaN
# 4                NaN   NaN
# 5                NaN   NaN
# 6                NaN   NaN
# 7                NaN   NaN
# 8                NaN   NaN
# 9                NaN   NaN
# 10               NaN   NaN
# 11               NaN   NaN
# 12               NaN   NaN
# 13               NaN   NaN
# 14               NaN   NaN
#
# [15 rows x 45 columns]

# %%
users.head(15)
# Out:
#     user_id  learning_time_ms                     start  \
# 0         1          14032710  2022-11-02T08:37:56.549Z
# 1         2          16268350  2022-09-07T07:53:38.865Z
# 2         3           8012030  2021-09-27T07:45:51.806Z
# 3         4           1414421  2019-11-12T12:18:15.724Z
# 4         5          17502108  2022-04-26T11:38:44.114Z
# 5         6           8353125  2022-09-02T07:27:20.675Z
# 6         7           7226229  2015-03-19T18:47:32.621Z
# 7         8          64629753  2021-08-23T09:04:32.478Z
# 8         9           7647781  2019-08-20T17:02:06.155Z
# 9        10          22569161  2017-08-30T06:27:19.365Z
# 10       11            190525  2015-05-18T07:07:41.143Z
# 11       12          14194844  2020-04-03T15:30:18.573Z
# 12       13            880193  2022-10-18T20:33:14.044Z
# 13       14          39935928  2021-08-13T07:24:25.301Z
# 14       15          45490997  2020-03-28T11:59:52.681Z
#
#                          end  logged_in_time_ms language country
# 0   2023-02-09T11:08:02.599Z           22151340       de      CH
# 1   2023-02-09T08:39:14.692Z           85421273       nl      NL
# 2   2022-01-13T12:14:09.565Z           16651482       de      DE
# 3   2020-10-02T09:20:28.798Z            4561768       de      CH
# 4   2022-08-29T15:52:11.087Z           25601470       de      CH
# 5   2023-02-01T10:35:15.218Z           19249399       nl      NL
# 6   2015-05-29T18:17:32.889Z            9225357      NaN     NaN
# 7   2022-06-20T12:13:06.081Z          125236245       de      CH
# 8   2020-03-08T14:08:06.321Z            9089877       de      DE
# 9   2021-07-08T14:09:17.450Z           33642991       de     NaN
# 10  2016-09-01T17:26:40.007Z            3037981       de     NaN
# 11  2020-09-24T08:53:11.378Z           25910399       de      CH
# 12  2022-10-18T20:53:07.434Z            1193389       fr      CA
# 13  2022-06-28T09:00:07.691Z           88997711       de      CH
# 14  2021-02-22T13:30:44.704Z           68277226       de      CH

# %%
# extract game_name and number_range from the events dataframe to match the subtasks dataframe (given the event_id)
game_name = subtasks.merge(events[['event_id', 'game_name']], on='event_id', how='left').game_name
number_range = subtasks.merge(events[['event_id', 'number_range']], on='event_id', how='left').number_range

#split the game_name into skills
skill = game_name.apply(lambda x: 'Number representation' 
                        if x in ['Subitizing', 'Conversion', 'Estimation', 'Estimation on Number Line', 'Scale: Conversion', 'Landing'] 
                        else 'Number comparison/manipulation' if x in ['Comparison', 'Secret Number', 'Distance', 'Scale: Composition', 'Order'] 
                        else 'Addition/Substraction' if x in ['Scale: Decomposition', 'Scale: Subtraction', 'Scale: Subtraction by Tens and Ones', 'Sliderule', 'Plus-minus', 'Difference', 'Completion', 'Calculator'] 
                        else 'Multiplication/Division' if x in ['Write as multiplication', 'Shelf: Jump Ahead', 'Shelf: given height', 'Shelf: random height', 'Distribution', 'Calculator: Multiplication', 'Calculator: Multiplication with ?', 'Calculator: Division', 'Jump backwards', 'Series'] 
                        else 'Other')

# concatenate skills and number range and add it to the subtasks dataframe
subtasks['skill_name'] = skill + ' ' + number_range
subtasks
# Out:
#        subtask_id  event_id  user_id      aim                    answer  \
# 0               0         0        1      NaN                         4
# 1               1         0        1      NaN                         1
# 2               2         1        1      NaN                         3
# 3               3         2        1      NaN                         5
# 4               4         3        1  3.00000  {'a': 2, 'b': 2.0402703}
# ...           ...       ...      ...      ...                       ...
# 55042       55042     37415      998 46.00000  {'a': 47, 'b': 47.33128}
# 55043       55043     37417     1000      NaN                         1
# 55044       55044     37417     1000      NaN                         2
# 55045       55045     37418     1000      NaN                         3
# 55046       55046     37419     1000      NaN                        10
#
#       answerMode availableNumbers  correct   correctAnswerObject  \
# 0            NaN              NaN     True                     4
# 1            NaN              NaN     True                   NaN
# 2            NaN              NaN     True                     3
# 3            NaN              NaN     True                     5
# 4            NaN              NaN    False    {'a': 3, 'b': 3.0}
# ...          ...              ...      ...                   ...
# 55042        NaN              NaN     True  {'a': 46, 'b': 46.0}
# 55043        NaN              NaN    False                     3
# 55044        NaN              NaN     True                   NaN
# 55045        NaN              NaN     True                     3
# 55046        NaN              NaN     True                    10
#
#        correctNumber  ... subtask_finished_timestamp  target  \
# 0            4.00000  ...   2022-11-02T08:39:24.930Z     NaN
# 1                NaN  ...   2022-11-02T08:39:24.930Z     NaN
# 2                NaN  ...   2022-11-11T10:26:49.007Z     NaN
# 3                NaN  ...   2022-11-18T10:34:12.191Z     NaN
# 4                NaN  ...   2022-11-25T10:32:56.805Z     NaN
# ...              ...  ...                        ...     ...
# 55042            NaN  ...   2021-01-06T14:14:46.133Z     NaN
# 55043        3.00000  ...   2019-09-30T10:04:58.024Z     NaN
# 55044            NaN  ...   2019-09-30T10:04:58.024Z     NaN
# 55045            NaN  ...   2020-01-20T10:03:51.556Z     NaN
# 55046            NaN  ...   2020-02-24T10:06:32.121Z     NaN
#
#        timeoutInSeconds timeoutInSteps                              type  \
# 0                   NaN            NaN  ConciseSubitizingTaskDescription
# 1               0.00000        2.00000         ConciseTimeoutDescription
# 2                   NaN            NaN  ConciseConversionTaskDescription
# 3                   NaN            NaN  ConciseConversionTaskDescription
# 4                   NaN            NaN     ConciseLandingTaskDescription
# ...                 ...            ...                               ...
# 55042               NaN            NaN     ConciseLandingTaskDescription
# 55043               NaN            NaN  ConciseSubitizingTaskDescription
# 55044           0.00000        2.00000         ConciseTimeoutDescription
# 55045               NaN            NaN  ConciseConversionTaskDescription
# 55046               NaN            NaN  ConciseConversionTaskDescription
#
#        upperBound  divisor orderIndependent  step                  skill_name
# 0             NaN      NaN              NaN   NaN   Number representation R10
# 1             NaN      NaN              NaN   NaN   Number representation R10
# 2             NaN      NaN              NaN   NaN   Number representation R10
# 3             NaN      NaN              NaN   NaN   Number representation R10
# 4         3.50000      NaN              NaN   NaN   Number representation R10
# ...           ...      ...              ...   ...                         ...
# 55042    50.00000      NaN              NaN   NaN  Number representation R100
# 55043         NaN      NaN              NaN   NaN   Number representation R10
# 55044         NaN      NaN              NaN   NaN   Number representation R10
# 55045         NaN      NaN              NaN   NaN   Number representation R10
# 55046         NaN      NaN              NaN   NaN   Number representation R10
#
# [55047 rows x 46 columns]

# %% [markdown]
# # BKT Model

# %%
#from pyBKT.models import Model
from pyBKT.models import Model

# %%
model = Model(seed=0, defaults={'order_id' : 'subtask_id'})
model.fit(data=subtasks, 
          multilearn = 'user_id',
          multigs = 'user_id',
          forgets = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 model = Model(seed=0, defaults={'order_id' : 'subtask_id'})
# ----> 2 model.fit(data=subtasks,
#       3           multilearn = 'user_id',
#       4           multigs = 'user_id',
#       5           forgets = True)
#
# File ~\anaconda3\envs\MLBD_env\lib\site-packages\pyBKT\models\Model.py:80, in Model.fit(self, data_path, data, **kwargs)
#      78 if not self.manual_param_init:
#      79     self.fit_model = {}
# ---> 80 self.partial_fit(data_path = data_path, data = data, **kwargs)
#
# File ~\anaconda3\envs\MLBD_env\lib\site-packages\pyBKT\models\Model.py:111, in Model.partial_fit(self, data_path, data, **kwargs)
#     109 self._update_param(['skills'], {'skills': list(all_data.keys())})
#     110 for skill in all_data:
# --> 111     self.fit_model[skill] = self._fit(all_data[skill], skill, self.forgets,
#     112                                       preload = kwargs['preload'] if 'preload' in kwargs else False)
#     113 self.manual_param_init = False
#
# File ~\anaconda3\envs\MLBD_env\lib\site-packages\pyBKT\models\Model.py:424, in Model._fit(self, data, skill, forgets, preload)
#     422             optional_args['fixed'][var] = self.fixed[skill][var]
#     423 if not preload:
# --> 424     fitmodel, log_likelihoods = EM_fit.EM_fit(fitmodel, data, parallel = self.parallel, **optional_args)
#     425     if log_likelihoods[-1] > best_likelihood:
#     426         best_likelihood = log_likelihoods[-1]
#
# File ~\anaconda3\envs\MLBD_env\lib\site-packages\pyBKT\fit\EM_fit.py:36, in EM_fit(model, data, tol, maxiter, parallel, fixed)
#      33 result['all_initial_softcounts'] = init_softcounts
#      35 for i in range(maxiter):
# ---> 36     result = run(data, model, result['all_trans_softcounts'], result['all_emission_softcounts'], result['all_initial_softcounts'], 1, parallel, fixed = fixed)
#      37     for j in range(num_resources):
#      38         result['all_trans_softcounts'][j] = result['all_trans_softcounts'][j].transpose()
#
# File ~\anaconda3\envs\MLBD_env\lib\site-packages\pyBKT\fit\EM_fit.py:109, in run(data, model, trans_softcounts, emission_softcounts, init_softcounts, num_outputs, parallel, fixed)
#     106     thread_counts[thread_num].update(input)
#     108 p = Pool(len(thread_counts))
# --> 109 x = p.map(inner, thread_counts)
#     110 p.close()
#     112 for i in x:
#
# File ~\anaconda3\envs\MLBD_env\lib\multiprocessing\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~\anaconda3\envs\MLBD_env\lib\multiprocessing\pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~\anaconda3\envs\MLBD_env\lib\multiprocessing\pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~\anaconda3\envs\MLBD_env\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~\anaconda3\envs\MLBD_env\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
params = model.params()
params

# %% [markdown]
# # DKT model

# %%
from sklearn import feature_extraction, model_selection

# %%
# Useful functions for what comes next
def create_iterator(data):
    '''
    Create an iterator to split interactions in data into train and test, with the same student not appearing in two diverse folds.
    :param data:        Dataframe with student's interactions.
    :return:            An iterator.
    '''    
    # Both passing a matrix with the raw data or just an array of indexes works
    X = np.arange(len(data.index)) 
    # Groups of interactions are identified by the user id (we do not want the same user appearing in two folds)
    groups = data['user_id'].values 
    return model_selection.GroupShuffleSplit(n_splits=1, train_size=.8, test_size=0.2, random_state=0).split(X, groups=groups)

def prepare_seq(df):
    # Step 1 - Enumerate skill id, each different skill has a different id
    df['skill'], skill_codes = pd.factorize(df['skill_name'], sort=True)

    # Step 2 - Cross skill id with answer to form a synthetic feature, being 2*skill_id + correct, which is 1 if subtask was correct, 0 else 
    df['skill_with_answer'] = df['skill'] * 2 + df['correct']

    # Step 3 - Convert to a sequence per user id and shift features 1 timestep, take all skill_with_answer except last value, take all skill and correct values except first
    seq = df.groupby('user_id').apply(lambda r: (r['skill_with_answer'].values[:-1], r['skill'].values[1:], r['correct'].values[1:],))
    
    # Step 4 - Get max skill depth and max feature depth
    skill_depth = df['skill'].max() 
    features_depth = df['skill_with_answer'].max() + 1

    return seq, features_depth, skill_depth

def prepare_data(seq, params, features_depth, skill_depth):
    
    # Step 1 - Transform sequence to Tensorflow Dataset
    dataset = tf.data.Dataset.from_generator(generator=lambda: seq, output_types=(tf.int32, tf.int32, tf.float32))

    # Step 2 - Encode categorical features and merge skills with labels to compute target loss.
    dataset = dataset.map(
        lambda feat, skill, label: (
            tf.one_hot(feat, depth=features_depth),
            tf.concat(values=[tf.one_hot(skill, depth=skill_depth), tf.expand_dims(label, -1)], axis=-1)
        )
    )

    # Step 3 - Pad sequences per batch
    dataset = dataset.padded_batch(
        batch_size=params['batch_size'],
        padding_values=(params['mask_value'], params['mask_value']),
        padded_shapes=([None, None], [None, None]),
        drop_remainder=True
    )

    return dataset.repeat(), len(seq)

# %% [markdown]
# ### Split data in train and test sets

# %%
# Obtain indexes
train_index, test_index = next(create_iterator(subtasks))
# Split the data
X_train, X_test = subtasks.iloc[train_index], subtasks.iloc[test_index]

# Split train data in train and validation sets
# Obtain indexes for necessary validation set
train_val_index, val_index = next(create_iterator(X_train))
# Split the training data into training and validation
X_train_val, X_val = X_train.iloc[train_val_index], X_train.iloc[val_index]

# %% [markdown]
# ### Data preparation

# %%
# Specify parameters
params = {}
params['batch_size'] = 32
params['mask_value'] = -1.0

# %%
# Prepare the data
seq, features_depth, skill_depth = prepare_seq(subtasks)
seq_train = seq[X_train.user_id.unique()]
seq_val = seq[X_train_val.user_id.unique()]
seq_test = seq[X_test.user_id.unique()]

tf_train, length = prepare_data(seq_train, params, features_depth, skill_depth)
tf_val, val_length  = prepare_data(seq_val, params, features_depth, skill_depth)
tf_test, test_length = prepare_data(seq_test, params, features_depth, skill_depth)

# Specify further params
params['train_size'] = int(length // params['batch_size'])
params['val_size'] = int(val_length // params['batch_size'])
params['test_size'] = int(test_length // params['batch_size'])

# %%
seq
# Out:
# user_id
# 1       ([25, 25, 25, 25, 24, 25, 24, 23, 23, 31, 31, ...
# 2       ([25, 25, 25, 25, 25, 25, 24, 24, 24, 24, 25, ...
# 3       ([24, 25, 16, 16, 23, 23, 23, 23, 27, 27, 26, ...
# 4                      ([24, 25], [12, 12], [True, True])
# 5       ([25, 25, 25, 31, 30, 31, 31, 30, 30, 27, 27, ...
#                               ...
# 995     ([25, 25, 25, 24, 30, 31, 26, 27, 19, 19, 19, ...
# 996     ([24, 25, 24, 25, 25, 25, 17, 17, 24, 25], [12...
# 997     ([24, 25, 25, 25, 24, 31, 23, 23, 23, 23, 23, ...
# 998     ([25, 25, 24, 25, 1, 25, 25, 24, 31, 31, 31, 3...
# 1000     ([24, 25, 25], [12, 12, 12], [True, True, True])
# Length: 926, dtype: object

# %% [markdown]
# ### Model creation

# %%
# Define model parameters
params['verbose'] = 1 # Verbose = {0,1,2}
params['best_model_weights'] = 'weights/bestmodel' # File to save the model
params['optimizer'] = 'adam' # Optimizer to use
params['backbone_nn'] = tf.keras.layers.RNN # Backbone neural network
params['recurrent_units'] = 16 # Number of RNN units
params['epochs'] = 10  # Number of epochs to train
params['dropout_rate'] = 0.3 # Dropout rate

# %%
# Function that removes predictions on time step associated with padding, and match outputs to specific skills
def get_target(y_true, y_pred, mask_value=params['mask_value']):
    
    # Get skills and labels from y_true
    mask = 1. - tf.cast(tf.equal(y_true, mask_value), y_true.dtype)
    y_true = y_true * mask

    skills, y_true = tf.split(y_true, num_or_size_splits=[-1, 1], axis=-1)

    # Get predictions for each skill
    y_pred = tf.reduce_sum(y_pred * skills, axis=-1, keepdims=True)

    return y_true, y_pred

# %%
# Define the metrics
class AUC(tf.keras.metrics.AUC):
    def update_state(self, y_true, y_pred, sample_weight=None):
        true, pred = get_target(y_true, y_pred)
        super(AUC, self).update_state(y_true=true, y_pred=pred, sample_weight=sample_weight)

class RMSE(tf.keras.metrics.RootMeanSquaredError):
    def update_state(self, y_true, y_pred, sample_weight=None):
        true, pred = get_target(y_true, y_pred)
        super(RMSE, self).update_state(y_true=true, y_pred=pred, sample_weight=sample_weight)
        
def CustomBinaryCrossEntropy(y_true, y_pred):    
    y_true, y_pred = get_target(y_true, y_pred)
    return tf.keras.losses.binary_crossentropy(y_true, y_pred)

# %%
# Model creation 
def create_model(nb_features, nb_skills, params):
    
    # Create the model architecture
    inputs = tf.keras.Input(shape=(None, nb_features), name='inputs')
    x = tf.keras.layers.Masking(mask_value=params['mask_value'])(inputs)
    x = tf.keras.layers.LSTM(params['recurrent_units'], return_sequences=True, dropout=params['dropout_rate'])(x)
    dense = tf.keras.layers.Dense(nb_skills, activation='sigmoid')
    outputs = tf.keras.layers.TimeDistributed(dense, name='outputs')(x)
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs, name='DKT')

    # Compile the model
    model.compile(loss=CustomBinaryCrossEntropy, 
                  optimizer=params['optimizer'], 
                  metrics=[AUC(), RMSE()])
    
    return model

model = create_model(features_depth, skill_depth, params)

# %%
model.summary()
# Out:
# Model: "DKT"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, None, 32)]        0
#
#  masking_1 (Masking)         (None, None, 32)          0
#
#  lstm_1 (LSTM)               (None, None, 16)          3136
#
#  outputs (TimeDistributed)   (None, None, 15)          255
#
# =================================================================
# Total params: 3,391
# Trainable params: 3,391
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model fitting and evaluation

# %%
# Model fit
ckp_callback = tf.keras.callbacks.ModelCheckpoint(params['best_model_weights'], save_best_only=True, save_weights_only=True)
history = model.fit(tf_train, epochs=params['epochs'], steps_per_epoch=params['train_size'], 
                    validation_data=tf_val,  validation_steps = params['val_size'], 
                    callbacks=[ckp_callback], verbose=params['verbose'])

# Model evaluation
model.load_weights(params['best_model_weights'])
metrics_dkt_small = model.evaluate(tf_test, verbose=params['verbose'], steps = params['test_size'])
# Out:
# Epoch 1/10
# 23/23 [==============================] - 4s 76ms/step - loss: 1.7038 - auc_1: 0.5788 - root_mean_squared_error: 0.5307 - val_loss: 1.6818 - val_auc_1: 0.5961 - val_root_mean_squared_error: 0.5174
# Epoch 2/10
# 23/23 [==============================] - 1s 45ms/step - loss: 1.6529 - auc_1: 0.5994 - root_mean_squared_error: 0.5070 - val_loss: 1.6185 - val_auc_1: 0.6086 - val_root_mean_squared_error: 0.4877
# Epoch 3/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5871 - auc_1: 0.6135 - root_mean_squared_error: 0.4774 - val_loss: 1.5650 - val_auc_1: 0.6216 - val_root_mean_squared_error: 0.4644
# Epoch 4/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5478 - auc_1: 0.6275 - root_mean_squared_error: 0.4599 - val_loss: 1.5399 - val_auc_1: 0.6388 - val_root_mean_squared_error: 0.4535
# Epoch 5/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5292 - auc_1: 0.6439 - root_mean_squared_error: 0.4518 - val_loss: 1.5267 - val_auc_1: 0.6558 - val_root_mean_squared_error: 0.4480
# Epoch 6/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5184 - auc_1: 0.6579 - root_mean_squared_error: 0.4474 - val_loss: 1.5189 - val_auc_1: 0.6682 - val_root_mean_squared_error: 0.4448
# Epoch 7/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5121 - auc_1: 0.6671 - root_mean_squared_error: 0.4448 - val_loss: 1.5137 - val_auc_1: 0.6748 - val_root_mean_squared_error: 0.4427
# Epoch 8/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5078 - auc_1: 0.6724 - root_mean_squared_error: 0.4432 - val_loss: 1.5101 - val_auc_1: 0.6790 - val_root_mean_squared_error: 0.4414
# Epoch 9/10
# 23/23 [==============================] - 1s 44ms/step - loss: 1.5052 - auc_1: 0.6760 - root_mean_squared_error: 0.4421 - val_loss: 1.5078 - val_auc_1: 0.6826 - val_root_mean_squared_error: 0.4405
# Epoch 10/10
# 23/23 [==============================] - 1s 43ms/step - loss: 1.5031 - auc_1: 0.6788 - root_mean_squared_error: 0.4413 - val_loss: 1.5060 - val_auc_1: 0.6856 - val_root_mean_squared_error: 0.4398
# 5/5 [==============================] - 0s 13ms/step - loss: 1.6922 - auc_1: 0.6680 - root_mean_squared_error: 0.4564

# %%
# Getting the metrics
# Binary cross entropy, AUC, RMSE
metrics_dkt_small
# Out:
# [1.6921628713607788, 0.6680315732955933, 0.45636826753616333]

# %%
prediction = model.predict(x = tf_val, steps = 5)
# Out:
# 5/5 [==============================] - 0s 15ms/step

# %%
prediction
# Out:
# <tf.RaggedTensor [[[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.7170984, 0.7721602, 0.5919929, ..., 0.6113148, 0.72336537, 0.58951926],
#   [0.7170984, 0.7721602, 0.5919929, ..., 0.6113148, 0.72336537, 0.58951926],
#   [0.7170984, 0.7721602, 0.5919929, ..., 0.6113148, 0.72336537, 0.58951926]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   ...,
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.70629984, 0.6806232, 0.5971227, ..., 0.68375504, 0.71774626,
#    0.65585417],
#   [0.70629984, 0.6806232, 0.5971227, ..., 0.68375504, 0.71774626,
#    0.65585417],
#   [0.70629984, 0.6806232, 0.5971227, ..., 0.68375504, 0.71774626,
#    0.65585417]]                                                             ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.715451, 0.76050544, 0.5872343, ..., 0.5659437, 0.7102286, 0.57133174],
#   [0.715451, 0.76050544, 0.5872343, ..., 0.5659437, 0.7102286, 0.57133174],
#   [0.715451, 0.76050544, 0.5872343, ..., 0.5659437, 0.7102286, 0.57133174]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.50496775, 0.627536, 0.65233773, ..., 0.55146, 0.5730462, 0.7858184],
#   [0.50496775, 0.627536, 0.65233773, ..., 0.55146, 0.5730462, 0.7858184],
#   [0.50496775, 0.627536, 0.65233773, ..., 0.55146, 0.5730462, 0.7858184]]   ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.60293293, 0.5395579, 0.5043257, ..., 0.55909216, 0.5434356, 0.5560162],
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845],
#   ...,
#   [0.7021474, 0.6204385, 0.62074465, ..., 0.68011045, 0.7156505, 0.6544891],
#   [0.7021474, 0.6204385, 0.62074465, ..., 0.68011045, 0.7156505, 0.6544891],
#   [0.7021474, 0.6204385, 0.62074465, ..., 0.68011045, 0.7156505, 0.6544891]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   ...,
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   ...,
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.6328058, 0.5737672, 0.5062294, ..., 0.55960304, 0.58094484, 0.5402714],
#   ...,
#   [0.54409623, 0.63458914, 0.6554152, ..., 0.5680656, 0.60328317,
#    0.7686326],
#   [0.54409623, 0.63458914, 0.6554152, ..., 0.5680656, 0.60328317,
#    0.7686326],
#   [0.54409623, 0.63458914, 0.6554152, ..., 0.5680656, 0.60328317,
#    0.7686326]]                                                              ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.
],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.67555356, 0.80544555, 0.6046346, ..., 0.70065695, 0.69169587,
#    0.6114073],
#   [0.67555356, 0.80544555, 0.6046346, ..., 0.70065695, 0.69169587,
#    0.6114073],
#   [0.67555356, 0.80544555, 0.6046346, ..., 0.70065695, 0.69169587,
#    0.6114073]]                                                             ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.5535184, 0.6404838, 0.6553607, ..., 0.57356024, 0.61309916, 0.765072],
#   [0.5535184, 0.6404838, 0.6553607, ..., 0.57356024, 0.61309916, 0.765072],
#   [0.5535184, 0.6404838, 0.6553607, ..., 0.57356024, 0.61309916, 0.765072]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.7059094, 0.7361483, 0.60594, ..., 0.68914217, 0.7094385, 0.6468423],
#   [0.7059094, 0.7361483, 0.60594, ..., 0.68914217, 0.7094385, 0.6468423],
#   [0.7059094, 0.7361483, 0.60594, ..., 0.68914217, 0.7094385, 0.6468423]]   ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.71212596, 0.62504065, 0.492773, ..., 0.62402153, 0.6483627,
#    0.59161365],
#   [0.71212596, 0.62504065, 0.492773, ..., 0.62402153, 0.6483627,
#    0.59161365],
#   [0.71212596, 0.62504065, 0.492773, ..., 0.62402153, 0.6483627,
#    0.59161365]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.72096854, 0.6625499, 0.49795038, ..., 0.60989416, 0.69509304,
#    0.60351276],
#   [0.72096854, 0.6625499, 0.49795038, ..., 0.60989416, 0.69509304,
#    0.60351276],
#   [0.72096854, 0.6625499, 0.49795038, ..., 0.60989416, 0.69509304,
#    0.60351276]]                                                            ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.75325894, 0.6524012, 0.5109812, ..., 0.6308959, 0.7076662, 0.6144228],
#   [0.75325894, 0.6524012, 0.5109812, ..., 0.6308959, 0.7076662, 0.6144228],
#   [0.75325894, 0.6524012, 0.5109812, ..., 0.6308959, 0.7076662, 0.6144228]] ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   ...,
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.68906796, 0.6660366, 0.6028942, ..., 0.681535, 0.7052618, 0.7063593],
#   [0.68906796, 0.6660366, 0.6028942, ..., 0.681535, 0.7052618, 0.7063593],
#   [0.68906796, 0.6660366, 0.6028942, ..., 0.681535, 0.7052618, 0.7063593]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.65928704, 0.76354134, 0.62302774, ..., 0.67923784, 0.6764997,
#    0.62304264],
#   [0.65928704, 0.76354134, 0.62302774, ..., 0.67923784, 0.6764997,
#    0.62304264],
#   [0.65928704, 0.76354134, 0.62302774, ..., 0.67923784, 0.6764997,
#    0.62304264]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63255465, 0.56457406, 0.4917443, ..., 0.5852808, 0.56696856,
#    0.5698931],
#   ...,
#   [0.60145885, 0.6479262, 0.6440958, ..., 0.5884502, 0.6654479, 0.76177347],
#   [0.60145885, 0.6479262, 0.6440958, ..., 0.5884502, 0.6654479, 0.76177347],
#   [0.60145885, 0.6479262, 0.6440958, ..., 0.5884502, 0.6654479, 0.76177347]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63661695, 0.574615, 0.499607, ..., 0.5942045, 0.57804847, 0.55207455],
#   ...,
#   [0.4950566, 0.61951655, 0.66198426, ..., 0.5576746, 0.57099056,
#    0.79911536],
#   [0.4950566, 0.61951655, 0.66198426, ..., 0.5576746, 0.57099056,
#    0.79911536],
#   [0.4950566, 0.61951655, 0.66198426, ..., 0.5576746, 0.57099056,
#    0.79911536]]                                                            ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.7005925, 0.69872653, 0.61698073, ..., 0.6807824, 0.7094279, 0.6824216],
#   [0.7005925, 0.69872653, 0.61698073, ..., 0.6807824, 0.7094279, 0.6824216],
#   [0.7005925, 0.69872653, 0.61698073, ..., 0.6807824, 0.7094279, 0.6824216]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036]]                                                              ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.5152317, 0.62857294, 0.65633994, ..., 0.5548534, 0.586117, 0.7820012],
#   [0.5152317, 0.62857294, 0.65633994, ..., 0.5548534, 0.586117, 0.7820012],
#   [0.5152317, 0.62857294, 0.65633994, ..., 0.5548534, 0.586117, 0.7820012]] ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.734228, 0.73276687, 0.5901734, ..., 0.6184914, 0.7241525, 0.5930593],
#   [0.734228, 0.73276687, 0.5901734, ..., 0.6184914, 0.7241525, 0.5930593],
#   [0.734228, 0.73276687, 0.5901734, ..., 0.6184914, 0.7241525, 0.5930593]] ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.5723682, 0.62506557, 0.65563947, ..., 0.58900976, 0.6292279,
#    0.7682573],
#   [0.5723682, 0.62506557, 0.65563947, ..., 0.58900976, 0.6292279,
#    0.7682573],
#   [0.5723682, 0.62506557, 0.65563947, ..., 0.58900976, 0.6292279,
#    0.7682573]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.60293293, 0.5395579, 0.5043257, ..., 0.55909216, 0.5434356, 0.5560162],
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845],
#   ...,
#   [0.72240466, 0.71778643, 0.5785583, ..., 0.6637004, 0.7345242, 0.6491055],
#   [0.72240466, 0.71778643, 0.5785583, ..., 0.6637004, 0.7345242, 0.6491055],
#   [0.72240466, 0.71778643, 0.5785583, ..., 0.6637004, 0.7345242, 0.6491055]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63661695, 0.574615, 0.499607, ..., 0.5942045, 0.57804847, 0.55207455],
#   ...,
# ...
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.70338464, 0.6867064, 0.61129224, ..., 0.67743486, 0.7064414,
#    0.6643776],
#   [0.70338464, 0.6867064, 0.61129224, ..., 0.67743486, 0.7064414,
#    0.6643776],
#   [0.70338464, 0.6867064, 0.61129224, ..., 0.67743486, 0.7064414,
#    0.6643776]]                                                              ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687]]                                                              ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6336284, 0.5837714, 0.49907154, ..., 0.609899, 0.5804384, 0.54784006],
#   ...,
#   [0.47174716, 0.6297463, 0.65762335, ..., 0.5438261, 0.55755967,
#    0.7933268],
#   [0.47174716, 0.6297463, 0.65762335, ..., 0.5438261, 0.55755967,
#    0.7933268],
#   [0.47174716, 0.6297463, 0.65762335, ..., 0.5438261, 0.55755967,
#    0.7933268]]                                                              ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63255465, 0.56457406, 0.4917443, ..., 0.5852808, 0.56696856,
#    0.5698931],
#   ...,
#   [0.6952331, 0.6341831, 0.6138238, ..., 0.69572973, 0.7071367, 0.6859203],
#   [0.6952331, 0.6341831, 0.6138238, ..., 0.69572973, 0.7071367, 0.6859203],
#   [0.6952331, 0.6341831, 0.6138238, ..., 0.69572973, 0.7071367, 0.6859203]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6103236, 0.5602551, 0.50082934, ..., 0.6053045, 0.5581644, 0.5577023],
#   ...,
#   [0.70209616, 0.65268654, 0.57415843, ..., 0.71167266, 0.7088631,
#    0.7009766],
#   [0.70209616, 0.65268654, 0.57415843, ..., 0.71167266, 0.7088631,
#    0.7009766],
#   [0.70209616, 0.65268654, 0.57415843, ..., 0.71167266, 0.7088631,
#    0.7009766]]                                                              ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.55454177, 0.6374597, 0.657204, ..., 0.57356226, 0.6169171, 0.7579616],
#   [0.55454177, 0.6374597, 0.657204, ..., 0.57356226, 0.6169171, 0.7579616],
#   [0.55454177, 0.6374597, 0.657204, ..., 0.57356226, 0.6169171, 0.7579616]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6103236, 0.5602551, 0.50082934, ..., 0.6053045, 0.5581644, 0.5577023],
#   ...,
#   [0.72864133, 0.64119613, 0.5550497, ..., 0.7284931, 0.7229956, 0.6683392],
#   [0.72864133, 0.64119613, 0.5550497, ..., 0.7284931, 0.7229956, 0.6683392],
#   [0.72864133, 0.64119613, 0.5550497, ..., 0.7284931, 0.7229956, 0.6683392]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63255465, 0.56457406, 0.4917443, ..., 0.5852808, 0.56696856,
#    0.5698931],
#   ...,
#   [0.7000161, 0.76977086, 0.5990806, ..., 0.61319464, 0.68529236,
#    0.5945749],
#   [0.7000161, 0.76977086, 0.5990806, ..., 0.61319464, 0.68529236,
#    0.5945749],
#   [0.7000161, 0.76977086, 0.5990806, ..., 0.61319464, 0.68529236,
#    0.5945749]]                                                            ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6103236, 0.5602551, 0.50082934, ..., 0.6053045, 0.5581644, 0.5577023],
#   ...,
#   [0.7083332, 0.6472131, 0.6271467, ..., 0.68206686, 0.7068025, 0.6743183],
#   [0.7083332, 0.6472131, 0.6271467, ..., 0.68206686, 0.7068025, 0.6743183],
#   [0.7083332, 0.6472131, 0.6271467, ..., 0.68206686, 0.7068025, 0.6743183]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.71022373, 0.6233082, 0.59175724, ..., 0.6989972, 0.7116004, 0.6871622],
#   [0.71022373, 0.6233082, 0.59175724, ..., 0.6989972, 0.7116004, 0.6871622],
#   [0.71022373, 0.6233082, 0.59175724, ..., 0.6989972, 0.7116004, 0.6871622]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.48764536, 0.61424774, 0.658079, ..., 0.5516571, 0.5594801, 0.8048022],
#   [0.5034062, 0.62242633, 0.6519121, ..., 0.5573061, 0.5597822, 0.79793656],
#   [0.5089115, 0.6145509, 0.65516716, ..., 0.55763066, 0.56876445,
#    0.7998575]]                                                              ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63255465, 0.56457406, 0.4917443, ..., 0.5852808, 0.56696856,
#    0.5698931],
#   ...,
#   [0.67748636, 0.806782, 0.6254249, ..., 0.6751312, 0.6763558, 0.6196995],
#   [0.67748636, 0.806782, 0.6254249, ..., 0.6751312, 0.6763558, 0.6196995],
#   [0.67748636, 0.806782, 0.6254249, ..., 0.6751312, 0.6763558, 0.6196995]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.60293293, 0.5395579, 0.5043257, ..., 0.55909216, 0.5434356, 0.5560162],
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845],
#   ...,
#   [0.6801184, 0.7992267, 0.61372715, ..., 0.67893857, 0.6781042,
#    0.61581755],
#   [0.6801184, 0.7992267, 0.61372715, ..., 0.67893857, 0.6781042,
#    0.61581755],
#   [0.6801184, 0.7992267, 0.61372715, ..., 0.67893857, 0.6781042,
#    0.61581755]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.60293293, 0.5395579, 0.5043257, ..., 0.55909216, 0.5434356, 0.5560162],
#   [0.6352339, 0.5533287, 0.4957912, ..., 0.56791455, 0.5633326, 0.5750073],
#   ...,
#   [0.6756829, 0.6364784, 0.6281808, ..., 0.6613529, 0.7048527, 0.7162142],
#   [0.6756829, 0.6364784, 0.6281808, ..., 0.6613529, 0.7048527, 0.7162142],
#   [0.6756829, 0.6364784, 0.6281808, ..., 0.6613529, 0.7048527, 0.7162142]]  ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.45481956, 0.6301784, 0.65943575, ..., 0.5390205, 0.5448642,
#    0.79979664],
#   [0.45481956, 0.6301784, 0.65943575, ..., 0.5390205, 0.5448642,
#    0.79979664],
#   [0.45481956, 0.6301784, 0.65943575, ..., 0.5390205, 0.5448642,
#    0.79979664]]                                                            ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6218778, 0.58773005, 0.48795396, ..., 0.62230724, 0.5653233,
#    0.5623036],
#   ...,
#   [0.55352217, 0.6331315, 0.6506852, ..., 0.5763509, 0.6213739, 0.7601496],
#   [0.55352217, 0.6331315, 0.6506852, ..., 0.5763509, 0.6213739, 0.7601496],
#   [0.55352217, 0.6331315, 0.6506852, ..., 0.5763509, 0.6213739, 0.7601496]] ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.6987082, 0.6694118, 0.575309, ..., 0.5980356, 0.6658516, 0.6166761],
#   [0.6987082, 0.6694118, 0.575309, ..., 0.5980356, 0.6658516, 0.6166761],
#   [0.6987082, 0.6694118, 0.575309, ..., 0.5980356, 0.6658516, 0.6166761]]   ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.60293293, 0.5395579, 0.5043257, ..., 0.55909216, 0.5434356, 0.5560162],
#   [0.6352339, 0.5533287, 0.4957912, ..., 0.56791455, 0.5633326, 0.5750073],
#   ...,
#   [0.72007585, 0.61555123, 0.6064344, ..., 0.69276816, 0.72623837,
#    0.6520017],
#   [0.72007585, 0.61555123, 0.6064344, ..., 0.69276816, 0.72623837,
#    0.6520017],
#   [0.72007585, 0.61555123, 0.6064344, ..., 0.69276816, 0.72623837,
#    0.6520017]]                                                              ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.6328058, 0.5737672, 0.5062294, ..., 0.55960304, 0.58094484, 0.5402714],
#   ...,
#   [0.58161646, 0.62913734, 0.6568196, ..., 0.59285, 0.6302055, 0.7687302],
#   [0.58161646, 0.62913734, 0.6568196, ..., 0.59285, 0.6302055, 0.7687302],
#   [0.58161646, 0.62913734, 0.6568196, ..., 0.59285, 0.6302055, 0.7687302]]  ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.65251666, 0.6029953, 0.48466924, ..., 0.62337846, 0.58905476,
#    0.5809625],
#   [0.65251666, 0.6029953, 0.48466924, ..., 0.62337846, 0.58905476,
#    0.5809625],
#   [0.65251666, 0.6029953, 0.48466924, ..., 0.62337846, 0.58905476,
#    0.5809625]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.6640571, 0.7074239, 0.61635435, ..., 0.65575653, 0.70203674,
#    0.6756735],
#   [0.6640571, 0.7074239, 0.61635435, ..., 0.65575653, 0.70203674,
#    0.6756735],
#   [0.6640571, 0.7074239, 0.61635435, ..., 0.65575653, 0.70203674,
#    0.6756735]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.6606615, 0.5889801, 0.4857852, ..., 0.6047872, 0.593541, 0.582676],
#   [0.6606615, 0.5889801, 0.4857852, ..., 0.6047872, 0.593541, 0.582676],
#   [0.6606615, 0.5889801, 0.4857852, ..., 0.6047872, 0.593541, 0.582676]]   ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.60293293, 0.5395579, 0.5043257, ..., 0.55909216, 0.5434356, 0.5560162],
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845],
#   ...,
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845],
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845],
#   [0.62915975, 0.5690661, 0.4926119, ..., 0.587164, 0.5619641, 0.5714845]]  ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.6363734, 0.6478146, 0.65205526, ..., 0.62725884, 0.6713177, 0.7403704],
#   [0.6363734, 0.6478146, 0.65205526, ..., 0.62725884, 0.6713177, 0.7403704],
#   [0.6363734, 0.6478146, 0.65205526, ..., 0.62725884, 0.6713177, 0.7403704]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.67974204, 0.7255834, 0.64626926, ..., 0.6544393, 0.6967119,
#    0.66160655],
#   [0.67974204, 0.7255834, 0.64626926, ..., 0.6544393, 0.6967119,
#    0.66160655],
#   [0.67974204, 0.7255834, 0.64626926, ..., 0.6544393, 0.6967119,
#    0.66160655]]                                                             ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.63661695, 0.574615, 0.499607, ..., 0.5942045, 0.57804847, 0.55207455],
#   ...,
#   [0.5372253, 0.609233, 0.63564116, ..., 0.582241, 0.61149144, 0.77593714],
#   [0.5372253, 0.609233, 0.63564116, ..., 0.582241, 0.61149144, 0.77593714],
#   [0.5372253, 0.609233, 0.63564116, ..., 0.582241, 0.61149144, 0.77593714]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.68752277, 0.7907178, 0.61798704, ..., 0.6437925, 0.6778294, 0.6122213],
#   [0.68752277, 0.7907178, 0.61798704, ..., 0.6437925, 0.6778294, 0.6122213],
#   [0.68752277, 0.7907178, 0.61798704, ..., 0.6437925, 0.6778294, 0.6122213]],
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.7205745, 0.76369834, 0.56196314, ..., 0.59832036, 0.7326568,
#    0.5789439],
#   [0.7205745, 0.76369834, 0.56196314, ..., 0.59832036, 0.7326568,
#    0.5789439],
#   [0.7205745, 0.76369834, 0.56196314, ..., 0.59832036, 0.7326568,
#    0.5789439]]                                                              ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.71772486, 0.7583765, 0.5691581, ..., 0.58209115, 0.7266554,
#    0.57240963],
#   [0.71772486, 0.7583765, 0.5691581, ..., 0.58209115, 0.7266554,
#    0.57240963],
#   [0.71772486, 0.7583765, 0.5691581, ..., 0.58209115, 0.7266554,
#    0.57240963]]                                                            ,
#  [[0.5643526, 0.539063, 0.5067277, ..., 0.5752451, 0.52491564, 0.53036386],
#   [0.59281737, 0.5631015, 0.49441013, ..., 0.6025807, 0.5426111, 0.5461789],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   ...,
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687],
#   [0.6308855, 0.57526565, 0.49107778, ..., 0.59989244, 0.5708284,
#    0.5656687]]                                                              ,
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   ...,
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871]],
#  [[0.5699824, 0.5274181, 0.5143932, ..., 0.54954123, 0.527062, 0.5363871],
#   [0.59659976, 0.5533096, 0.49897668, ..., 0.582076, 0.54126, 0.5508278],
#   [0.624559, 0.5786082, 0.48866338, ..., 0.6066368, 0.5631904, 0.56637645],
#   ...,
#   [0.60471356, 0.639591, 0.6570722, ..., 0.60167044, 0.63599247, 0.7507878],
#   [0.60471356, 0.639591, 0.6570722, ..., 0.60167044, 0.63599247, 0.7507878],
#   [0.60471356, 0.639591, 0.6570722, ..., 0.60167044, 0.63599247, 0.7507878]]]>

# %%
X_val
# Out:
#        subtask_id  event_id  user_id      aim                     answer  \
# 14             14        12        2      NaN                          1
# 15             15        12        2      NaN                          1
# 16             16        13        2      NaN                          2
# 17             17        13        2      NaN                          0
# 18             18        14        2      NaN                          2
# ...           ...       ...      ...      ...                        ...
# 55008       55008     37387      997 19.00000  {'a': 19, 'b': 19.173439}
# 55009       55009     37388      997      NaN                          8
# 55010       55010     37389      997  4.00000   {'a': 4, 'b': 3.5028758}
# 55011       55011     37390      997      NaN                         20
# 55012       55012     37391      997      NaN                          8
#
#       answerMode availableNumbers  correct   correctAnswerObject  \
# 14           NaN              NaN     True                     1
# 15           NaN              NaN     True                   NaN
# 16           NaN              NaN     True                     2
# 17           NaN              NaN     True                   NaN
# 18           NaN              NaN     True                     2
# ...          ...              ...      ...                   ...
# 55008        NaN              NaN     True  {'a': 19, 'b': 19.0}
# 55009        NaN              NaN     True                     8
# 55010        NaN              NaN     True    {'a': 4, 'b': 4.0}
# 55011        NaN              NaN     True                    20
# 55012     RESULT              NaN     True                     8
#
#        correctNumber  ... subtask_finished_timestamp  target  \
# 14           1.00000  ...   2022-09-07T07:55:20.991Z     NaN
# 15               NaN  ...   2022-09-07T07:55:20.991Z     NaN
# 16           2.00000  ...   2022-09-13T09:03:55.646Z     NaN
# 17               NaN  ...   2022-09-13T09:03:55.646Z     NaN
# 18           2.00000  ...   2022-09-14T07:24:54.895Z     NaN
# ...              ...  ...                        ...     ...
# 55008            NaN  ...   2021-06-07T11:26:45.986Z     NaN
# 55009            NaN  ...   2021-06-10T09:33:23.334Z     NaN
# 55010            NaN  ...   2021-06-10T09:38:38.457Z     NaN
# 55011            NaN  ...   2021-06-14T10:23:24.287Z     NaN
# 55012            NaN  ...   2021-06-14T11:08:58.433Z     NaN
#
#        timeoutInSeconds timeoutInSteps                              type  \
# 14                  NaN            NaN  ConciseSubitizingTaskDescription
# 15              0.00000        2.00000         ConciseTimeoutDescription
# 16                  NaN            NaN  ConciseSubitizingTaskDescription
# 17              0.00000        2.00000         ConciseTimeoutDescription
# 18                  NaN            NaN  ConciseSubitizingTaskDescription
# ...                 ...            ...                               ...
# 55008               NaN            NaN     ConciseLandingTaskDescription
# 55009               NaN            NaN  ConciseConversionTaskDescription
# 55010               NaN            NaN     ConciseLandingTaskDescription
# 55011               NaN            NaN  ConciseConversionTaskDescription
# 55012               NaN            NaN    ConciseEquationTaskDescription
#
#        upperBound  divisor orderIndependent  step                 skill_name
# 14            NaN      NaN              NaN   NaN  Number representation R10
# 15            NaN      NaN              NaN   NaN  Number representation R10
# 16            NaN      NaN              NaN   NaN  Number representation R10
# 17            NaN      NaN              NaN   NaN  Number representation R10
# 18            NaN      NaN              NaN   NaN  Number representation R10
# ...           ...      ...              ...   ...                        ...
# 55008    20.00000      NaN              NaN   NaN  Number representation R20
# 55009         NaN      NaN              NaN   NaN  Number representation R20
# 55010     5.00000      NaN              NaN   NaN  Number representation R20
# 55011         NaN      NaN              NaN   NaN  Number representation R20
# 55012         NaN      NaN              NaN   NaN  Addition/Substraction R20
#
# [7692 rows x 46 columns]
